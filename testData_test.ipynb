# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

X = np.load('train_data_maybe/x_train.npy')
Y = np.load('train_data_maybe/y_train.npy')

y1 = Y[0]
x1 = X[0]

yWithCrosswalk = [(index,y) for (index,y) in enumerate(Y) if 1 in y][0]


plt.imshow(X[yWithCrosswalk[0]])
plt.show()
plt.figure(0)
plt.imshow(yWithCrosswalk[1])
plt.show()
plt.figure(0)

plt.imshow(x1)
plt.show()
plt.figure(0)
plt.imshow(y1)
plt.show()

# %%
#test numpy
import numpy as np

initData1 = [4000,4000,4000,4000,4000,4000,4000,4000]
initData2 = [10,10,10,10,10,10,10,10]

np1 = np.array(initData1)
np2 = np.array(initData2)
np2 = np2.astype(np.dtype(np.int8))

np3 = np.concatenate([np1,np2])
print(np3)
np3 = np3.astype(np.dtype(np.int8))
for n in np3:
    print(n.dtype)
print(np3)
# Out:
# [4000 4000 4000 4000 4000 4000 4000 4000   10   10   10   10   10   10
#    10   10]
# int8
# int8
# int8
# int8
# int8
# int8
# int8
# int8
# int8
# int8
# int8
# int8
# int8
# int8
# int8
# int8
# [-96 -96 -96 -96 -96 -96 -96 -96  10  10  10  10  10  10  10  10]
